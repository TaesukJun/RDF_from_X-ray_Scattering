# %%
from sympy.solvers import solve
from sympy import Symbol




x = Symbol('x')
solve(x**3 - 1, x)
# Out:
# [1, -1/2 - sqrt(3)*I/2, -1/2 + sqrt(3)*I/2]

# %%
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list
    (100, 100, 47.86, 15.24), # Intensity of 10 nm at 0 h
    (55.55, 72.7, 100, 100), # Intensity of 100nm at 0 h
    (96.33, 100, 41.355, 15.033), # Intensity of 10nm at 2 h
    (100, 97, 100, 100),  # Intensity of 100nm at 2 h
    (2.30, 2.02, 1.87, 1.78) # Count rate ratio compared 0 h to 2 h
]

# data by data
conc = 0 # Please note conc list
RP = 3 # Rayleigh Assumption of Power Constant
Polymer2h_ratio = 1.4 # PNIPAM-PEG count rate ratio between 0 h and 2 h

eq_01 = (data[1][conc] - 2.5 * a) # a = optical coef. of IgG at 0 h
eq_02 = (data[2][conc] - data[0][conc] * b) # b = optical coef. of Polymer at 0 h
eq_03 = (data[3][conc] * data[5][conc] - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = optical coef. of Non-aggregated IgG
eq_04 = (data[4][conc] * data[5][conc] - e * f - g * h) # e = wt. conc of Polymer at 2 h # f = optical coef. of Poylmer at 2 h # g = optical coef. of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
eq_05 = (2.5 - c - g)
eq_06 = (e - data[0][conc])
eq_07 = (d / h - 11**RP/50**RP)
# eq_08 = (b / a - f / d)
eq_08 = (Polymer2h_ratio * b - f)

# a = optical coef. of IgG at 0 h
# b = optical coef. of Polymer at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = optical coef. of Non-aggregated IgG
# e = wt. conc. of Polymer at 2 h 
# f = optical coef. of Poylmer at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = optical coef. of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
print(answer[0][e])
print(answer[0][f])
print(answer[0][g])
print(answer[0][h])
# Out:
# [100 - 2.5*a, 55.55 - 0.3*b, -c*d + 221.559, -e*f - g*h + 230.0, -c - g + 2.5, e - 0.3, d/h - 0.010648, 1.4*b - f]
# [{a: 40.0000000000000, b: 185.166666666667, c: 2.48184262210803, d: 89.2719780160000, e: 0.300000000000000, f: 259.233333333333, g: 0.0181573778919683, h: 8383.91979864763}]
# 40.0000000000000
# 185.166666666667
# 2.48184262210803
# 89.2719780160000
# 0.300000000000000
# 259.233333333333
# 0.0181573778919683
# 8383.91979864763

# %%
# solve([300 - 2.5 * a, 200 - 2.5 * b, 500 - c * d, 400 - e * f + g * h, 2.5 - c - g, e - 2.5, d / f - 27, a / b - c / e])

# %%
data = [
    (0.3, 0.5, 1.5, 2.5), # conc list
    (100, 100, 47.86, 15.84), # Intensity of 10 nm at 0 h
    (55.55, 72.7, 100, 100), # Intensity of 100nm at 0 h
    (55.55, 72.7, 100, 100) # Intensity of 100nm at 0 h
    
    
    
    
    
]
print(data[0][0])
# Out:
# 0.3

# %%
# For Tween 80 cases:

from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list for Tween 80
    (100, 100, 100, 100), # Intensity of 10 nm at 0 h
    (32, 54.8, 82.1, 100), # Intensity of 10nm at 2 h
    (100, 100, 100, 52.69),  # Intensity of 100nm at 2 h
    (2.32, 2.12, 1.95, 1.81) # Count rate ratio compared 0 h to 2 h
]

# data by data
conc = 0 # Please note conc list
RP = 3 # Rayleigh Assumption of Power Constant
Tween2h_ratio = 1 # Tween 80 thermal count rate ratio between 0 h and 2 h
Tween_IgG_ratio = 1.2

eq_01 = (data[1][conc] - 2.5 * a - data[0][conc] * b) 
eq_02 = (data[2][conc] * data[4][conc] - c * d - e * f) 
eq_03 = (data[3][conc] * data[4][conc] - g * h)
eq_04 = (2.5 - c - g)
eq_05 = (e - data[0][conc])
eq_06 = (d / h - 11**RP/50**RP)
eq_07 = (b / a - Tween_IgG_ratio)
eq_08 = (f / d - Tween_IgG_ratio)

# a = optical coef. of IgG at 0 h
# b = optical coef. of Tween 80 at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = optical coef. of Non-aggregated IgG at 2 h
# e = wt. conc. of Tween 80 at 2 h 
# f = optical coef. of Tween 80 at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = optical coef. of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
print(answer[0][e])
print(answer[0][f])
print(answer[0][g])
print(answer[0][h])
# Out:
# [-2.5*a - 0.3*b + 100, -c*d - e*f + 74.24, -g*h + 232.0, -c - g + 2.5, e - 0.3, d/h - 0.010648, -1.2 + b/a, -1.2 + f/d]
# [{a: 34.9650349650350, b: 41.9580419580420, c: 2.40789818780092, d: 26.8217958041958, e: 0.300000000000000, f: 32.1861549650350, g: 0.0921018121990758, h: 2518.95152180652}]
# 34.9650349650350
# 41.9580419580420
# 2.40789818780092
# 26.8217958041958
# 0.300000000000000
# 32.1861549650350
# 0.0921018121990758
# 2518.95152180652

# %%
# simple case for only IgG
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

eq_01 = (32.02 * 2.55 - a * b) 
eq_02 = (100 * 2.55 - c * d) 
eq_03 = (2.5 - a - c) 
eq_04 = (d - 50**3/11**3 * b) 

# a = wt.conc of Nonaggregated IgG at 2 h
# b = optical coef. of Nonaggregated IgG at 2 h
# c = wt. conc. of Aggregated IgG at 2 h 
# d = optical coef. of Aggregated IgG at 2 h

eqs = [eq_01, eq_02, eq_03, eq_04]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
# Out:
# [-a*b + 81.651, -c*d + 255.0, -a - c + 2.5, -93.9143501126972*b + d]
# [{a: 2.41954009091788, b: 33.7464960000000, c: 0.0804599090821163, d: 3169.28024042074}]
# 2.41954009091788
# 33.7464960000000
# 0.0804599090821163
# 3169.28024042074

# %%
# simple case for only IgG
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

eq_01 = (100 * 2.55 - a * b) 
eq_02 = (62.16 * 2.55 - c * d) 
eq_03 = (2.5 - a - c) 
eq_04 = (d - 50**3/11**3 * b) 

# a = wt.conc of Nonaggregated IgG at 2 h
# b = optical coef. of Nonaggregated IgG at 2 h
# c = wt. conc. of Aggregated IgG at 2 h 
# d = optical coef. of Aggregated IgG at 2 h

eqs = [eq_01, eq_02, eq_03, eq_04]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
# Out:
# [-a*b + 255.0, -c*d + 158.508, -a - c + 2.5, -93.9143501126972*b + d]
# [{a: 2.48356180904569, b: 102.675117273600, c: 0.0164381909543138, d: 9642.66691149511}]
# 2.48356180904569
# 102.675117273600
# 0.0164381909543138
# 9642.66691149511

# %%
"""
for items in answer:
    for item in items:
        print(item)
        print("\n")
"""

# %%
# For Tween 80 cases

from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list
    (100, 100, 47.86, 15.84), # Intensity of 10 nm at 0 h
    (55.55, 72.7, 100, 100), # Intensity of 100nm at 0 h
    (14.23, 41.355, 100, 96.33), # Intensity of 10nm at 2 h
    (100, 100, 97, 100),  # Intensity of 100nm at 2 h
    (2.30, 2.02, 1.87, 1.78) # Count rate ratio compared 0 h to 2 h
]




eq_01 = (100- 2.5 * a) # a = optical coef. of IgG at 0 h
eq_02 = (55.55 - Pconc * b) # b = optical coef. of Polymer at 0 h
eq_03 = (96.33 * Amp - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = optical coef. of Non-aggregated IgG
eq_04 = (100 * Amp - e * f - g * h) # e = wt. conc of Polymer at 2 h # f = optical coef. of Poylmer at 2 h # g = optical coef. of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
eq_05 = (2.5 - c - g)
eq_06 = (e - Pconc)
eq_07 = (d / f - 50**3/11**3)
eq_08 = (a / b - c / e)

# a = optical coef. of IgG at 0 h
# b = optical coef. of Polymer at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = optical coef. of Non-aggregated IgG
# e = wt. conc. of Polymer at 2 h 
# f = optical coef. of Poylmer at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = optical coef. of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
print(answer[0][e])
print(answer[0][f])
print(answer[0][g])
print(answer[0][h])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 21
#       8 data = [
#       9     (0.3, 0.5, 1.5, 2.5), # conc list
#      10     (100, 100, 47.86, 15.84), # Intensity of 10 nm at 0 h
#    (...)
#      14     (2.30, 2.02, 1.87, 1.78) # Count rate ratio compared 0 h to 2 h
#      15 ]
#      20 eq_01 = (100- 2.5 * a) # a = optical coef. of IgG at 0 h
# ---> 21 eq_02 = (55.55 - Pconc * b) # b = optical coef. of Polymer at 0 h
#      22 eq_03 = (96.33 * Amp - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = optical coef. of Non-aggregated IgG
#      23 eq_04 = (100 * Amp - e * f - g * h) # e = wt. conc of Polymer at 2 h # f = optical coef. of Poylmer at 2 h # g = optical coef. of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
#
# NameError: name 'Pconc' is not defined

# %%
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

#solve([x + y - 3, y**2 + x - 1])

# relative count rate at 2 h compared to 0 h
Amp = 1.78
    # 2.30 for 0.3 mg/ml Polymer
    # 2.02 for 0.5 mg/ml
    # 1.87 for 1.5 mg/ml
    # 1.78 for 2.5 mg/ml


eq_01 = (15.8 - 2.5 * a) # a = activity of IgG at 0 h
eq_02 = (100 - 2.5 * b) # b = activity of Polymer at 0 h
eq_03 = (14.2 * Amp - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = activity of Non-aggregated IgG
eq_04 = (100 * Amp - e * f + g * h) # e = wt. conc of Polymer at 2 h # f = activity of Poylmer at 2 h # g = activity of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
eq_05 = (2.5 - c - g)
eq_06 = (e - 2.5)
eq_07 = (d / f - 50**3/11**3)
eq_08 = (a / b - c / e)

# a = activity of IgG at 0 h
# b = activity of Polymer at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = activity of Non-aggregated IgG
# e = wt. conc. of Polymer at 2 h 
# f = activity of Poylmer at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = actvity of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eq)

solve(eqs)
# solve([300 - 2.5 * a, 200 - 2.5 * b, 500 - c * d, 400 - e * f + g * h, 2.5 - c - g, e - 2.5, d / f - 27, a / b - c / e])

# %%
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list
    (100, 100, 47.86, 28.04), # Intensity of 10 nm at 0 h
    (55.55, 69.7, 100, 100), # Intensity of 100nm at 0 h
    (65.33, 72.8, 42.355, 24.13), # Intensity of 10nm at 2 h
    (100, 100, 100, 100),  # Intensity of 100nm at 2 h
    (2.12, 2.01, 1.69, 1.48) # Count rate ratio compared 0 h to 2 h
]

# data by data
# conc = 0 # Please note conc list
RP = 3 # Rayleigh Assumption of Power Constant
Polymer2h_ratio = 1.4 # PNIPAM-PEG count rate ratio between 0 h and 2 h

for conc in range(0,4):
    print("Case conc: %f" %(data[0][conc]))

    eq_01 = (data[1][conc] - 2.5 * a) # a = optical coef. of IgG at 0 h
    eq_02 = (data[2][conc] - data[0][conc] * b) # b = optical coef. of Polymer at 0 h
    eq_03 = (data[3][conc] * data[5][conc] - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = optical coef. of Non-aggregated IgG
    eq_04 = (data[4][conc] * data[5][conc] - e * f - g * h) # e = wt. conc of Polymer at 2 h # f = optical coef. of Poylmer at 2 h # g = optical coef. of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
    eq_05 = (2.5 - c - g)
    eq_06 = (e - data[0][conc])
    eq_07 = (d / h - 11**RP/50**RP)
    # eq_08 = (b / a - f / d)
    eq_08 = (Polymer2h_ratio * b - f)

    # a = optical coef. of IgG at 0 h
    # b = optical coef. of Polymer at 0 h
    # c = wt. conc. of Non-aggregated IgG at 2 h 
    # d = optical coef. of Non-aggregated IgG
    # e = wt. conc. of Polymer at 2 h 
    # f = optical coef. of Poylmer at 2 h 
    # g = wt. conc. of Aggregated IgG at 2h 
    # h = optical coef. of Aggregated IgG at 2h

    eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
    print(eqs)

    answer = solve(eqs, dict=True, set=True, simplify=True)
    print(answer)
    print(answer[0][a])
    print(answer[0][b])
    print(answer[0][c])
    print(answer[0][d])
    print(answer[0][e])
    print(answer[0][f])
    print(answer[0][g])
    print(answer[0][h])
    print("")
# Out:
# Case conc: 0.300000
# [100 - 2.5*a, 55.55 - 0.3*b, -c*d + 138.4996, -e*f - g*h + 212.0, -c - g + 2.5, e - 0.3, d/h - 0.010648, 1.4*b - f]
# [{a: 40.0000000000000, b: 185.166666666667, c: 2.47446415226476, d: 55.9715524160000, e: 0.300000000000000, f: 259.233333333333, g: 0.0255358477352403, h: 5256.53196994741}]
# 40.0000000000000
# 185.166666666667
# 2.47446415226476
# 55.9715524160000
# 0.300000000000000
# 259.233333333333
# 0.0255358477352403
# 5256.53196994741
#
# Case conc: 0.500000
# [100 - 2.5*a, 69.7 - 0.5*b, -c*d + 146.328, -e*f - g*h + 201.0, -c - g + 2.5, e - 0.5, d/h - 0.010648, 1.4*b - f]
# [{a: 40.0000000000000, b: 139.400000000000, c: 2.48132635801975, d: 58.9716864640000, e: 0.500000000000000, f: 195.160000000000, g: 0.0186736419802451, h: 5538.28760931630}]
# 40.0000000000000
# 139.400000000000
# 2.48132635801975
# 58.9716864640000
# 0.500000000000000
# 195.160000000000
# 0.0186736419802451
# 5538.28760931630
#
# Case conc: 1.500000
# [47.86 - 2.5*a, 100 - 1.5*b, -c*d + 71.57995, -e*f - g*h + 169.0, -c - g + 2.5, e - 1.5, d/h - 0.010648, 1.4*b - f]
# [{a: 19.1440000000000, b: 66.6666666666667, c: 2.48926146182945, d: 28.7554968000000, e: 1.50000000000000, f: 93.3333333333333, g: 0.0107385381705525, h: 2700.55379413974}]
# 19.1440000000000
# 66.6666666666667
# 2.48926146182945
# 28.7554968000000
# 1.50000000000000
# 93.3333333333333
# 0.0107385381705525
# 2700.55379413974
#
# Case conc: 2.500000
# [28.04 - 2.5*a, 100 - 2.5*b, -c*d + 35.7124, -e*f - g*h + 148.0, -c - g + 2.5, e - 2.5, d/h - 0.010648, 1.4*b - f]
# [{a: 11.2160000000000, b: 40.0000000000000, c: 2.49405099517331, d: 14.3190336000000, e: 2.50000000000000, f: 56.0000000000000, g: 0.00594900482669445, h: 1344.76273478588}]
# 11.2160000000000
# 40.0000000000000
# 2.49405099517331
# 14.3190336000000
# 2.50000000000000
# 56.0000000000000
# 0.00594900482669445
# 1344.76273478588

# %%
# For Tween 80 cases:

from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list for Tween 80
    (100, 100, 100, 100), # Intensity of 10 nm at 0 h
    (43, 54.8, 90.1, 100), # Intensity of 10nm at 2 h
    (100, 100, 100, 55.69),  # Intensity of 100nm at 2 h
    (2.32, 2.12, 1.91, 1.81) # Count rate ratio compared 0 h to 2 h
]

# data by data
# conc = 0 # Please note conc list
RP = 3 # Rayleigh Assumption of Power Constant
Tween2h_ratio = 1 # Tween 80 thermal count rate ratio between 0 h and 2 h
Tween_IgG_ratio = 1.2

for conc in range(0,4):
    print("Case conc: %f" %(data[0][conc]))

    eq_01 = (data[1][conc] - 2.5 * a - data[0][conc] * b) 
    eq_02 = (data[2][conc] * data[4][conc] - c * d - e * f) 
    eq_03 = (data[3][conc] * data[4][conc] - g * h)
    eq_04 = (2.5 - c - g)
    eq_05 = (e - data[0][conc])
    eq_06 = (d / h - 11**RP/50**RP)
    eq_07 = (b / a - Tween_IgG_ratio)
    eq_08 = (f / d - Tween_IgG_ratio)

    # a = optical coef. of IgG at 0 h
    # b = optical coef. of Tween 80 at 0 h
    # c = wt. conc. of Non-aggregated IgG at 2 h 
    # d = optical coef. of Non-aggregated IgG at 2 h
    # e = wt. conc. of Tween 80 at 2 h 
    # f = optical coef. of Tween 80 at 2 h 
    # g = wt. conc. of Aggregated IgG at 2h 
    # h = optical coef. of Aggregated IgG at 2h

    eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
    print(eqs)

    answer = solve(eqs, dict=True, set=True, simplify=True)
    print(answer)
    print(answer[0][a])
    print(answer[0][b])
    print(answer[0][c])
    print(answer[0][d])
    print(answer[0][e])
    print(answer[0][f])
    print(answer[0][g])
    print(answer[0][h])
    print("")
# Out:
# Case conc: 0.300000
# [-2.5*a - 0.3*b + 100, -c*d - e*f + 99.76, -g*h + 232.0, -c - g + 2.5, e - 0.3, d/h - 0.010648, -1.2 + b/a, -1.2 + f/d]
# [{a: 34.9650349650350, b: 41.9580419580420, c: 2.43088978050507, d: 35.7448727272727, e: 0.300000000000000, f: 42.8938472727273, g: 0.0691102194949257, h: 3356.95649204289}]
# 34.9650349650350
# 41.9580419580420
# 2.43088978050507
# 35.7448727272727
# 0.300000000000000
# 42.8938472727273
# 0.0691102194949257
# 3356.95649204289
#
# Case conc: 0.500000
# [-2.5*a - 0.5*b + 100, -c*d - e*f + 116.176, -g*h + 212.0, -c - g + 2.5, e - 0.5, d/h - 0.010648, -1.2 + b/a, -1.2 + f/d]
# [{a: 32.2580645161290, b: 38.7096774193548, c: 2.44091306153428, d: 38.2043148387097, e: 0.500000000000000, f: 45.8451778064516, g: 0.0590869384657244, h: 3587.93339957829}]
# 32.2580645161290
# 38.7096774193548
# 2.44091306153428
# 38.2043148387097
# 0.500000000000000
# 45.8451778064516
# 0.0590869384657244
# 3587.93339957829
#
# Case conc: 1.500000
# [-2.5*a - 1.5*b + 100, -c*d - e*f + 172.091, -g*h + 191.0, -c - g + 2.5, e - 1.5, d/h - 0.010648, -1.2 + b/a, -1.2 + f/d]
# [{a: 23.2558139534884, b: 27.9069767441860, c: 2.44977622942188, d: 40.4941320930233, e: 1.50000000000000, f: 48.5929585116279, g: 0.0502237705781179, h: 3802.98009889399}]
# 23.2558139534884
# 27.9069767441860
# 2.44977622942188
# 40.4941320930233
# 1.50000000000000
# 48.5929585116279
# 0.0502237705781179
# 3802.98009889399
#
# Case conc: 2.500000
# [-2.5*a - 2.5*b + 100, -c*d - e*f + 181.0, -g*h + 100.7989, -c - g + 2.5, e - 2.5, d/h - 0.010648, -1.2 + b/a, -1.2 + f/d]
# [{a: 18.1818181818182, b: 21.8181818181818, c: 2.46757796688044, d: 33.1042375794909, e: 2.50000000000000, f: 39.7250850953891, g: 0.0324220331195589, h: 3108.96295825422}]
# 18.1818181818182
# 21.8181818181818
# 2.46757796688044
# 33.1042375794909
# 2.50000000000000
# 39.7250850953891
# 0.0324220331195589
# 3108.96295825422
