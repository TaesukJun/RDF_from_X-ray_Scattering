# %%
from sympy.solvers import solve
from sympy import Symbol




x = Symbol('x')
solve(x**2 - 1, x)
# Out:
# [-1, 1]

# %%
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list
    (100, 100, 47.86, 15.84), # Intensity of 10 nm at 0 h
    (55.55, 72.7, 100, 100), # Intensity of 100nm at 0 h
    (96.33, 100, 41.355, 14.233), # Intensity of 10nm at 2 h
    (100, 97, 100, 100),  # Intensity of 100nm at 2 h
    (2.30, 2.02, 1.87, 1.78) # Count rate ratio compared 0 h to 2 h
]

# data by data
conc = 3 # Please note conc list
RP = 3 # Rayleigh Assumption of Power Constant
Polymer2h_ratio = 1.16 # PNIPAM-PEG count rate ratio between 0 h and 2 h

eq_01 = (data[1][conc] - 2.5 * a) # a = optical coef. of IgG at 0 h
eq_02 = (data[2][conc] - data[0][conc] * b) # b = optical coef. of Polymer at 0 h
eq_03 = (data[3][conc] * data[5][conc] - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = optical coef. of Non-aggregated IgG
eq_04 = (data[4][conc] * data[5][conc] - e * f - g * h) # e = wt. conc of Polymer at 2 h # f = optical coef. of Poylmer at 2 h # g = optical coef. of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
eq_05 = (2.5 - c - g)
eq_06 = (e - data[0][conc])
eq_07 = (d / h - 11**RP/50**RP)
eq_08 = (b / a - f / d)

# a = optical coef. of IgG at 0 h
# b = optical coef. of Polymer at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = optical coef. of Non-aggregated IgG
# e = wt. conc. of Polymer at 2 h 
# f = optical coef. of Poylmer at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = optical coef. of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
print(answer[0][e])
print(answer[0][f])
print(answer[0][g])
print(answer[0][h])
# Out:
# [15.84 - 2.5*a, 100 - 2.5*b, -c*d + 25.33474, -e*f - g*h + 178.0, -c - g + 2.5, e - 2.5, d/h - 0.010648, -f/d + b/a]
# [{a: 6.33600000000000, b: 40.0000000000000, c: 2.48234613619097, d: 10.2059658927642, e: 2.50000000000000, f: 64.4316028583598, g: 0.0176538638090299, h: 958.486654091302}]
# 6.33600000000000
# 40.0000000000000
# 2.48234613619097
# 10.2059658927642
# 2.50000000000000
# 64.4316028583598
# 0.0176538638090299
# 958.486654091302

# %%
# solve([300 - 2.5 * a, 200 - 2.5 * b, 500 - c * d, 400 - e * f + g * h, 2.5 - c - g, e - 2.5, d / f - 27, a / b - c / e])

# %%
data = [
    (0.3, 0.5, 1.5, 2.5), # conc list
    (100, 100, 47.86, 15.84), # Intensity of 10 nm at 0 h
    (55.55, 72.7, 100, 100), # Intensity of 100nm at 0 h
    (55.55, 72.7, 100, 100) # Intensity of 100nm at 0 h
    
    
    
    
    
]
print(data[0][0])
# Out:
# 0.3

# %%
# For Tween 80 cases:

from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list for Tween 80
    (100, 100, 100, 100), # Intensity of 10 nm at 0 h
    (43.5, 53.8, 82.1, 92.4), # Intensity of 10nm at 2 h
    (100, 100, 100, 52.69),  # Intensity of 100nm at 2 h
    (2.32, 2.12, 1.95, 1.81) # Count rate ratio compared 0 h to 2 h
]

"""
data = [
    (0.3, 0.5, 1.5, 2.5), # conc list for Tween 80
    (100, 100, 100, 100), # Intensity of 10 nm at 0 h
    (32, 54.8, 82.1, 100), # Intensity of 10nm at 2 h
    (100, 100, 100, 52.69),  # Intensity of 100nm at 2 h
    (2.32, 2.12, 1.95, 1.81) # Count rate ratio compared 0 h to 2 h
]
"""

# data by data
conc = 2 # Please note conc list
RP = 3 # Rayleigh Assumption of Power Constant
Tween2h_ratio = 1 # Tween 80 thermal count rate ratio between 0 h and 2 h
Tween_IgG_ratio = 910/700 # The count ratio with identical weight concentration

eq_01 = (data[1][conc] - 2.5 * a - data[0][conc] * b) 
eq_02 = (data[2][conc] * data[4][conc] - c * d - e * f) 
eq_03 = (data[3][conc] * data[4][conc] - g * h)
eq_04 = (2.5 - c - g)
eq_05 = (e - data[0][conc])
eq_06 = (d / h - 11**RP/50**RP)
eq_07 = (b / a - Tween_IgG_ratio)
eq_08 = (f / d - Tween_IgG_ratio)

# a = optical coef. of IgG at 0 h
# b = optical coef. of Tween 80 at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = optical coef. of Non-aggregated IgG at 2 h
# e = wt. conc. of Tween 80 at 2 h 
# f = optical coef. of Tween 80 at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = optical coef. of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
print(answer[0][e])
print(answer[0][f])
print(answer[0][g])
print(answer[0][h])
# Out:
# [-2.5*a - 1.5*b + 100, -c*d - e*f + 160.095, -g*h + 195.0, -c - g + 2.5, e - 1.5, d/h - 0.010648, -1.3 + b/a, -1.3 + f/d]
# [{a: 22.4719101123596, b: 29.2134831460674, c: 2.44302445265305, d: 36.4430022471910, e: 1.50000000000000, f: 47.3759029213483, g: 0.0569755473469545, h: 3422.52087220051}]
# 22.4719101123596
# 29.2134831460674
# 2.44302445265305
# 36.4430022471910
# 1.50000000000000
# 47.3759029213483
# 0.0569755473469545
# 3422.52087220051

# %%
# For Tween 80 cases:

from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list for Tween 80
    (100, 100, 100, 100), # Intensity of 10 nm at 0 h
    (43.5, 53.8, 82.1, 92.4), # Intensity of 10nm at 2 h
    (100, 100, 100, 52.69),  # Intensity of 100nm at 2 h
    (2.32, 2.12, 1.95, 1.81) # Count rate ratio compared 0 h to 2 h
]

"""
data = [
    (0.3, 0.5, 1.5, 2.5), # conc list for Tween 80
    (100, 100, 100, 100), # Intensity of 10 nm at 0 h
    (32, 54.8, 82.1, 100), # Intensity of 10nm at 2 h
    (100, 100, 100, 52.69),  # Intensity of 100nm at 2 h
    (2.32, 2.12, 1.95, 1.81) # Count rate ratio compared 0 h to 2 h
]
"""

# Whole date
for conc in range(4):
    #conc = 2 # Please note conc list
    RP = 3 # Rayleigh Assumption of Power Constant
    Tween2h_ratio = 1 # Tween 80 thermal count rate ratio between 0 h and 2 h
    Tween_IgG_ratio = 910/700

    eq_01 = (data[1][conc] - 2.5 * a - data[0][conc] * b) 
    eq_02 = (data[2][conc] * data[4][conc] - c * d - e * f) 
    eq_03 = (data[3][conc] * data[4][conc] - g * h)
    eq_04 = (2.5 - c - g)
    eq_05 = (e - data[0][conc])
    eq_06 = (d / h - 11**RP/50**RP)
    eq_07 = (b / a - Tween_IgG_ratio)
    eq_08 = (f / d - Tween_IgG_ratio)

    # a = optical coef. of IgG at 0 h
    # b = optical coef. of Tween 80 at 0 h
    # c = wt. conc. of Non-aggregated IgG at 2 h 
    # d = optical coef. of Non-aggregated IgG at 2 h
    # e = wt. conc. of Tween 80 at 2 h 
    # f = optical coef. of Tween 80 at 2 h 
    # g = wt. conc. of Aggregated IgG at 2h 
    # h = optical coef. of Aggregated IgG at 2h

    print("conc.: "+str(data[0][conc]))

    eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
    print(eqs)

    answer = solve(eqs, dict=True, set=True, simplify=True)
    print(answer)
    print(answer[0][a])
    print(answer[0][b])
    print(answer[0][c])
    print(answer[0][d])
    print(answer[0][e])
    print(answer[0][f])
    print(answer[0][g])
    print(answer[0][h])
# Out:
# conc.: 0.3
# [-2.5*a - 0.3*b + 100, -c*d - e*f + 100.92, -g*h + 232.0, -c - g + 2.5, e - 0.3, d/h - 0.010648, -1.3 + b/a, -1.3 + f/d]
# [{a: 34.6020761245675, b: 44.9826989619377, c: 2.43094837180914, d: 35.7752027681661, e: 0.300000000000000, f: 46.5077635986159, g: 0.0690516281908592, h: 3359.80491812229}]
# 34.6020761245675
# 44.9826989619377
# 2.43094837180914
# 35.7752027681661
# 0.300000000000000
# 46.5077635986159
# 0.0690516281908592
# 3359.80491812229
# conc.: 0.5
# [-2.5*a - 0.5*b + 100, -c*d - e*f + 114.056, -g*h + 212.0, -c - g + 2.5, e - 0.5, d/h - 0.010648, -1.3 + b/a, -1.3 + f/d]
# [{a: 31.7460317460317, b: 41.2698412698413, c: 2.43886572082647, d: 36.9248812698413, e: 0.500000000000000, f: 48.0023456507937, g: 0.0611342791735320, h: 3467.77622744565}]
# 31.7460317460317
# 41.2698412698413
# 2.43886572082647
# 36.9248812698413
# 0.500000000000000
# 48.0023456507937
# 0.0611342791735320
# 3467.77622744565
# conc.: 1.5
# [-2.5*a - 1.5*b + 100, -c*d - e*f + 160.095, -g*h + 195.0, -c - g + 2.5, e - 1.5, d/h - 0.010648, -1.3 + b/a, -1.3 + f/d]
# [{a: 22.4719101123596, b: 29.2134831460674, c: 2.44302445265305, d: 36.4430022471910, e: 1.50000000000000, f: 47.3759029213483, g: 0.0569755473469545, h: 3422.52087220051}]
# 22.4719101123596
# 29.2134831460674
# 2.44302445265305
# 36.4430022471910
# 1.50000000000000
# 47.3759029213483
# 0.0569755473469545
# 3422.52087220051
# conc.: 2.5
# [-2.5*a - 2.5*b + 100, -c*d - e*f + 167.244, -g*h + 95.3689, -c - g + 2.5, e - 2.5, d/h - 0.010648, -1.3 + b/a, -1.3 + f/d]
# [{a: 17.3913043478261, b: 22.6086956521739, c: 2.46529731345812, d: 29.2625196603826, e: 2.50000000000000, f: 38.0412755584974, g: 0.0347026865418848, h: 2748.17051656486}]
# 17.3913043478261
# 22.6086956521739
# 2.46529731345812
# 29.2625196603826
# 2.50000000000000
# 38.0412755584974
# 0.0347026865418848
# 2748.17051656486

# %%
# simple case for only IgG
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

#eq_01 = (32.02 * 2.55 - a * b) 
#eq_02 = (100 * 2.55 - c * d) 
eq_01 = (100 * 2.55 - a * b) 
eq_02 = (62 * 2.55 - c * d) 
eq_03 = (2.5 - a - c) 
eq_04 = (d - 50**3/11**3 * b) 

# a = wt.conc of Nonaggregated IgG at 2 h
# b = optical coef. of Nonaggregated IgG at 2 h
# c = wt. conc. of Aggregated IgG at 2 h 
# d = optical coef. of Aggregated IgG at 2 h

eqs = [eq_01, eq_02, eq_03, eq_04]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
# Out:
# [-a*b + 255.0, -c*d + 158.1, -a - c + 2.5, -93.9143501126972*b + d]
# [{a: 2.48360384349020, b: 102.673379520000, c: 0.0163961565097999, d: 9642.50371149511}]
# 2.48360384349020
# 102.673379520000
# 0.0163961565097999
# 9642.50371149511

# %%
"""
for items in answer:
    for item in items:
        print(item)
        print("\n")
"""

# %%
# For Tween 80 cases

from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

# relative count rate at 2 h compared to 0 h

data = [
    (0.3, 0.5, 1.5, 2.5), # conc list
    (100, 100, 47.86, 15.84), # Intensity of 10 nm at 0 h
    (55.55, 72.7, 100, 100), # Intensity of 100nm at 0 h
    (14.23, 41.355, 100, 96.33), # Intensity of 10nm at 2 h
    (100, 100, 97, 100),  # Intensity of 100nm at 2 h
    (2.30, 2.02, 1.87, 1.78) # Count rate ratio compared 0 h to 2 h
]




eq_01 = (100- 2.5 * a) # a = optical coef. of IgG at 0 h
eq_02 = (55.55 - Pconc * b) # b = optical coef. of Polymer at 0 h
eq_03 = (96.33 * Amp - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = optical coef. of Non-aggregated IgG
eq_04 = (100 * Amp - e * f - g * h) # e = wt. conc of Polymer at 2 h # f = optical coef. of Poylmer at 2 h # g = optical coef. of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
eq_05 = (2.5 - c - g)
eq_06 = (e - Pconc)
eq_07 = (d / f - 50**3/11**3)
eq_08 = (a / b - c / e)

# a = optical coef. of IgG at 0 h
# b = optical coef. of Polymer at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = optical coef. of Non-aggregated IgG
# e = wt. conc. of Polymer at 2 h 
# f = optical coef. of Poylmer at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = optical coef. of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eqs)

answer = solve(eqs, dict=True, set=True, simplify=True)
print(answer)
print(answer[0][a])
print(answer[0][b])
print(answer[0][c])
print(answer[0][d])
print(answer[0][e])
print(answer[0][f])
print(answer[0][g])
print(answer[0][h])

# %%
from sympy import solve, Poly, Eq, Matrix, Symbol
from sympy.abc import x, y, z, a, b, c, d, e, f, g, h

#solve([x + y - 3, y**2 + x - 1])

# relative count rate at 2 h compared to 0 h
Amp = 1.78
    # 2.30 for 0.3 mg/ml Polymer
    # 2.02 for 0.5 mg/ml
    # 1.87 for 1.5 mg/ml
    # 1.78 for 2.5 mg/ml


eq_01 = (15.8 - 2.5 * a) # a = activity of IgG at 0 h
eq_02 = (100 - 2.5 * b) # b = activity of Polymer at 0 h
eq_03 = (14.2 * Amp - c * d) # c = wt. conc. of Non-aggregated IgG at 2 h # d = activity of Non-aggregated IgG
eq_04 = (100 * Amp - e * f + g * h) # e = wt. conc of Polymer at 2 h # f = activity of Poylmer at 2 h # g = activity of Aggregated IgG at 2h # h = actvity of Aggregated IgG at 2h
eq_05 = (2.5 - c - g)
eq_06 = (e - 2.5)
eq_07 = (d / f - 50**3/11**3)
eq_08 = (a / b - c / e)

# a = activity of IgG at 0 h
# b = activity of Polymer at 0 h
# c = wt. conc. of Non-aggregated IgG at 2 h 
# d = activity of Non-aggregated IgG
# e = wt. conc. of Polymer at 2 h 
# f = activity of Poylmer at 2 h 
# g = wt. conc. of Aggregated IgG at 2h 
# h = actvity of Aggregated IgG at 2h

eqs = [eq_01, eq_02, eq_03, eq_04, eq_05, eq_06, eq_07, eq_08]
print(eq)

solve(eqs)
# solve([300 - 2.5 * a, 200 - 2.5 * b, 500 - c * d, 400 - e * f + g * h, 2.5 - c - g, e - 2.5, d / f - 27, a / b - c / e])
